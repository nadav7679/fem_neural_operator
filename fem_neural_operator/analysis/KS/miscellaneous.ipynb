# %%
from firedrake import *
import torch
import matplotlib.pyplot as plt
import os
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from classes import *
# Out:
# /home/clustor/ma/n/np923/fem_neural_operator/firedrake/lib/python3.10/site-packages/pytools/persistent_dict.py:59: UserWarning: Unable to import recommended hash 'siphash24.siphash13', falling back to 'hashlib.sha256'. Run 'python3 -m pip install siphash24' to install the recommended hash.
#   warn("Unable to import recommended hash 'siphash24.siphash13', "
# firedrake:WARNING OMP_NUM_THREADS is not set or is set to a value greater than 1, we suggest setting OMP_NUM_THREADS=1 to improve performance

# %%
ncells = 100
L = 10.
mesh = PeriodicIntervalMesh(ncells, L)

V = FunctionSpace(mesh, "HER", 3)

un = Function(V)
unp1 = Function(V)

uh = (un + unp1)/2

v = TestFunction(V)

dt = 0.01
dT = Constant(dt)

# alpha = Constant(1.0)
# beta = Constant(0.02923)
# gamma = Constant(1.)

nu = Constant(0.029)

eqn = (
    v*(unp1 - un)
    - dT*v.dx(0)*uh.dx(0)
    + dT*nu*v.dx(0).dx(0)*uh.dx(0).dx(0)
    - dT*0.5*v.dx(0)*uh*uh
    )*dx

params = {
    "snes_atol": 1.0e-50,
    "snes_rtol": 1.0e-6,
    "snes_stol": 1.0e-50,
    "ksp_type":"preonly",
    "pc_type":"lu"
}

#make the solver
KSProb = NonlinearVariationalProblem(eqn, unp1)
KSSolver = NonlinearVariationalSolver(KSProb,
                                      solver_parameters=params)

#initial condition

x, = SpatialCoordinate(mesh)
un.project(-sin(pi*2*x/L))
# Out:
# Coefficient(WithGeometry(FunctionSpace(<firedrake.mesh.MeshTopology object at 0x7fdcf4c62fe0>, FiniteElement('Hermite', interval, 3), name=None), Mesh(VectorElement(FiniteElement('Discontinuous Lagrange', interval, 1, variant='equispaced'), dim=1, variant='equispaced'), 405)), 443)

# %%
import time
from IPython import display

t=0.
tmax = 10.
tdump = 1.
dumpt = 0.

# file0 = File("stuff.pvd")
VOut = FunctionSpace(mesh, "CG", 3)
uout = Function(VOut)
uout.interpolate(un)
# file0.write(uout)

fig, axes = plt.subplots()
hdisplay = display.display("", display_id=True)

observable = []
t_range = []
integrals = []
while t < tmax - dt/2:
    axes.cla()
    axes.set_ylim([-15, 15])

    t += dt

    KSSolver.solve()
    un.assign(unp1)


    uout.interpolate(un)
    
    curr_norm = norm(un)
    curr_int = assemble(un * dx)
    integrals.append(curr_int)
    observable.append(curr_norm)
    t_range.append(t)
    
    axes.set_title("$\Vert u \Vert_{L^2} = " + f"{curr_norm}$")

    plot(uout, axes=axes)
    hdisplay.update(fig)

# %%
observable = np.array(observable)
dEdt = np.gradient(observable, dt)

# %%
fig, axes = plt.subplots(2, 1, figsize=(7, 7), sharex=True)

axes[0].plot(t_range, observable)
axes[0].set_title("KS L2 norm vs time - Sinusoidal Initial Condition")
axes[0].set_ylabel("$\Vert u(x, t) \Vert_{L^2}$")
axes[0].grid()

axes[1].plot(t_range, integrals)
axes[1].set_title("Overall integral vs time")
axes[1].set_xlabel("$t$")
axes[1].set_ylabel("$\int u(x, t) dx$")
axes[1].grid()


plt.savefig("KS L2 norm and error plot")

# %%
plt.scatter(observable, dEdt, marker="+")
plt.title("L2 norm Phase Plot")
plt.ylabel("$\partial_t \Vert u(x, t) \Vert_{L^2}$")
plt.xlabel("$\Vert u(x, t) \Vert_{L^2}$")
plt.grid()

plt.savefig("KS L2 phase plot")

# %%
# The error is close to zero
# Out:
# Text(0, 0.5, '$\\int u(x, t) dx$')

# %%
N = 4096
L = 10.
T = 0.5
nu = 0.029
dt = 0.01
samples = 600

with CheckpointFile(f"/home/clustor2/ma/n/np923/fem_neural_operator/fem_neural_operator/data/KS/meshes/N{N}.h5", "r") as f:
    mesh = f.load_mesh()
    
fs = FunctionSpace(mesh, "HER", 3) 
fs_out = FunctionSpace(mesh, "CG", 3)


# data = torch.load(f"/home/clustor2/ma/n/np923/fem_neural_operator/fem_neural_operator/data/KS/samples/N{N}_nu{nu}_T{T}_samples{samples}_batch1.pt")

# %%
index = 55

func_in_her = Function(fs, val=data[index, 0, :].numpy())
func_out_her = Function(fs, val=data[index, 1, :].numpy())

func_in = Function(fs_out)
func_out = Function(fs_out)

func_in.interpolate(func_in_her)
func_out.interpolate(func_out_her)

fig, axes = plt.subplots()

plot(func_in, axes=axes, label="Input")
plot(func_out, axes=axes, label="Output")
axes.legend()
axes.set_title(f"Datapoint {index}")
# Out:
# Text(0.5, 1.0, 'Datapoint 55')

# %%
from classes import Dataset
from torch.utils.data.dataloader import DataLoader

device = torch.device("cuda")
N = 4096

samples = torch.load(f"../../data/KS/samples/N{N}_HER_nu0029_T01_samples1200.pt").unsqueeze(2).to(device=device, dtype=torch.float64)
print(samples.shape)
grid = torch.linspace(0, 1, 2 * N, device=device)
dataset = Dataset(samples, grid)
print(dataset.inputs.shape, dataset.targets.shape)

trainset = dataset[:1000]  # Cutting off the train data
testset = dataset[1000:]

loader = DataLoader(trainset, 32)
# Out:
# torch.Size([1200, 2, 1, 8192])
# torch.Size([1200, 2, 8192]) torch.Size([1200, 1, 8192])

# %%
for x, y in loader:
    print(x.shape, y.shape)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 for x, y in loader:
#       2     print(x.shape, y.shape)
#
# File /home/clustor2/ma/n/np923/firedrake/lib/python3.10/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File /home/clustor2/ma/n/np923/firedrake/lib/python3.10/site-packages/torch/utils/data/dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /home/clustor2/ma/n/np923/firedrake/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:54, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
# ---> 54 return self.collate_fn(data)
#
# File /home/clustor2/ma/n/np923/firedrake/lib/python3.10/site-packages/torch/utils/data/_utils/collate.py:316, in default_collate(batch)
#     255 def default_collate(batch):
#     256     r"""
#     257     Take in a batch of data and put the elements within the batch into a tensor with an additional outer dimension - batch size.
#     258
#    (...)
#     314         >>> default_collate(batch)  # Handle `CustomType` automatically
#     315     """
# --> 316     return collate(batch, collate_fn_map=default_collate_fn_map)
#
# File /home/clustor2/ma/n/np923/firedrake/lib/python3.10/site-packages/torch/utils/data/_utils/collate.py:141, in collate(batch, collate_fn_map)
#     139 if collate_fn_map is not None:
#     140     if elem_type in collate_fn_map:
# --> 141         return collate_fn_map[elem_type](batch, collate_fn_map=collate_fn_map)
#     143     for collate_type in collate_fn_map:
#     144         if isinstance(elem, collate_type):
#
# File /home/clustor2/ma/n/np923/firedrake/lib/python3.10/site-packages/torch/utils/data/_utils/collate.py:213, in collate_tensor_fn(batch, collate_fn_map)
#     211     storage = elem._typed_storage()._new_shared(numel, device=elem.device)
#     212     out = elem.new(storage).resize_(len(batch), *list(elem.size()))
# --> 213 return torch.stack(batch, 0, out=out)
#
# RuntimeError: stack expects each tensor to be equal size, but got [1000, 2, 8192] at entry 0 and [1000, 1, 8192] at entry 1

# %%
samples = (torch.load(f"playground/data/burgers/samples/N8192_nu0.01_samples40_batch1.pt")
            .unsqueeze(2).to(device=device, dtype=torch.float64))
grid = torch.linspace(0, 1, 8192, device=device)
dataset = BurgersDataset(samples, grid)
burger_loader = DataLoader(dataset, 32)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 samples = (torch.load(f"playground/data/burgers/samples/N8192_nu0.01_samples40_batch1.pt")
#       2             .unsqueeze(2).to(device=device, dtype=torch.float64))
#       3 grid = torch.linspace(0, 1, 8192, device=device)
#       4 dataset = BurgersDataset(samples, grid)
#
# File /home/clustor2/ma/n/np923/firedrake/lib/python3.10/site-packages/torch/serialization.py:997, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#     994 if 'encoding' not in pickle_load_args.keys():
#     995     pickle_load_args['encoding'] = 'utf-8'
# --> 997 with _open_file_like(f, 'rb') as opened_file:
#     998     if _is_zipfile(opened_file):
#     999         # The zipfile reader is going to advance the current file position.
#    1000         # If we want to actually tail call to torch.jit.load, we need to
#    1001         # reset back to the original position.
#    1002         orig_position = opened_file.tell()
#
# File /home/clustor2/ma/n/np923/firedrake/lib/python3.10/site-packages/torch/serialization.py:444, in _open_file_like(name_or_buffer, mode)
#     442 def _open_file_like(name_or_buffer, mode):
#     443     if _is_path(name_or_buffer):
# --> 444         return _open_file(name_or_buffer, mode)
#     445     else:
#     446         if 'w' in mode:
#
# File /home/clustor2/ma/n/np923/firedrake/lib/python3.10/site-packages/torch/serialization.py:425, in _open_file.__init__(self, name, mode)
#     424 def __init__(self, name, mode):
# --> 425     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'playground/data/burgers/samples/N8192_nu0.01_samples40_batch1.pt'

# %%
for x, y in burger_loader:
    print(x.shape, y.shape)
# Out:
# torch.Size([32, 2, 8192]) torch.Size([32, 1, 8192])
# torch.Size([8, 2, 8192]) torch.Size([8, 1, 8192])

# %%
device = torch.device("cuda")

samples = torch.load(f"data/burgers/samples/N8192_nu0.01_samples40_batch1.pt").unsqueeze(2).to(device=device, dtype=torch.float64)
print(samples.shape)

with CheckpointFile(f"/home/clustor2/ma/n/np923/fem_neural_operator/playground/data/KS/meshes/N4096.h5", "r") as f:
    mesh1 = f.load_mesh()

with CheckpointFile(f"/home/clustor2/ma/n/np923/fem_neural_operator/playground/data/KS/meshes/N512.h5", "r") as f:
    mesh2 = f.load_mesh()
# Out:
# torch.Size([40, 2, 1, 8192])

# %%
her1 = FunctionSpace(mesh1, "HER", 3)
her2 = FunctionSpace(mesh2, "HER", 3) 
cg1 = FunctionSpace(mesh1, "CG", 3)
cg2 = FunctionSpace(mesh2, "CG", 1)

# %%
index = 20
func_her1 = Function(her1, val=samples[index, 0, :].cpu().numpy())
func_her2 = Function(her2)
func_cg2 = Function(cg2)
func_cg1 = Function(cg1)

func_cg1.interpolate(func_her1)
func_cg2.interpolate(func_cg1)
func_her2.project(func_cg2)
# Out:
# Coefficient(WithGeometry(FunctionSpace(<firedrake.mesh.MeshTopology object at 0x7fae47c4d810>, FiniteElement('Hermite', interval, 3), name=None), Mesh(VectorElement(FiniteElement('Discontinuous Lagrange', interval, 1, variant='equispaced'), dim=1, variant='equispaced'), 3)), 188)

# %%
# %matplotlib widget

func_cg2_projected = Function(cg2)
func_cg2_projected.interpolate(func_her2)

fig, axes = plt.subplots()
plot(func_cg1, axes=axes, label="HER1 -> interpolate -> CG1")
plot(func_cg2, axes=axes, label="CG1 -> interpolate -> CG2")
plot(func_cg2_projected, axes=axes, label="CG2 -> project -> HER2 -> interpolate -> CG2")
axes.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
index = 20
func_her1 = Function(her1, val=samples[index, 0, :].cpu().numpy())
func_cg2 = Function(cg2)
func_cg2.project(func_her1)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[22], line 4
#       2 func_her1 = Function(her1, val=samples[index, 0, :].cpu().numpy())
#       3 func_cg2 = Function(cg2)
# ----> 4 func_cg2.project(func_her1)
#
# File petsc4py/PETSc/Log.pyx:188, in petsc4py.PETSc.Log.EventDecorator.decorator.wrapped_func()
#
# File petsc4py/PETSc/Log.pyx:189, in petsc4py.PETSc.Log.EventDecorator.decorator.wrapped_func()
#
# File /home/clustor2/ma/n/np923/firedrake/src/firedrake/firedrake/adjoint_utils/function.py:47, in FunctionMixin._ad_annotate_project.<locals>.wrapper(self, b, *args, **kwargs)
#      44     tape.add_block(block)
#      46 with stop_annotating():
# ---> 47     output = project(self, b, *args, **kwargs)
#      49 if annotate:
#      50     block.add_output(output.create_block_variable())
#
# File /home/clustor2/ma/n/np923/firedrake/src/firedrake/firedrake/function.py:363, in Function.project(self, b, *args, **kwargs)
#     355 r"""Project ``b`` onto ``self``. ``b`` must be a :class:`Function` or a
#     356 UFL expression.
#     357
#    (...)
#     360 may also be passed, and they will have their usual effect.
#     361 """
#     362 from firedrake import projection
# --> 363 return projection.project(b, self, *args, **kwargs)
#
# File petsc4py/PETSc/Log.pyx:188, in petsc4py.PETSc.Log.EventDecorator.decorator.wrapped_func()
#
# File petsc4py/PETSc/Log.pyx:189, in petsc4py.PETSc.Log.EventDecorator.decorator.wrapped_func()
#
# File /home/clustor2/ma/n/np923/firedrake/src/firedrake/firedrake/adjoint_utils/projection.py:34, in annotate_project.<locals>.wrapper(*args, **kwargs)
#      31             block = ProjectBlock(args[0], V, output, bcs, ad_block_tag=ad_block_tag, **sb_kwargs)
#      33 with stop_annotating():
# ---> 34     output = project(*args, **kwargs)
#      36 if annotate:
#      37     tape = get_working_tape()
#
# File /home/clustor2/ma/n/np923/firedrake/src/firedrake/firedrake/projection.py:79, in project(v, V, bcs, solver_parameters, form_compiler_parameters, use_slate_for_inverse, name, ad_block_tag)
#      49 @PETSc.Log.EventDecorator()
#      50 @annotate_project
#      51 def project(v, V, bcs=None,
#    (...)
#      55             name=None,
#      56             ad_block_tag=None):
#      57     """Project a UFL expression into a :class:`.FunctionSpace`
#      58     It is possible to project onto the trace space 'DGT', but not onto
#      59     other trace spaces e.g. into the restriction of CG onto the facets.
#    (...)
#      74     then ``v`` is projected into a new :class:`.Function` and that
#      75     :class:`.Function` is returned."""
#      77     val = Projector(v, V, bcs=bcs, solver_parameters=solver_parameters,
#      78                     form_compiler_parameters=form_compiler_parameters,
# ---> 79                     use_slate_for_inverse=use_slate_for_inverse).project()
#      80     val.rename(name)
#      81     return val
#
# File /home/clustor2/ma/n/np923/firedrake/src/firedrake/firedrake/projection.py:182, in ProjectorBase.project(self)
#     181 def project(self):
# --> 182     self.apply_massinv(self.target, self.rhs)
#     183     return self.target
#
# File /home/clustor2/ma/n/np923/firedrake/src/firedrake/firedrake/projection.py:241, in SupermeshProjector.rhs(self)
#     238 @property
#     239 def rhs(self):
#     240     with self.source.dat.vec_ro as u, self.residual.dat.vec_wo as v:
# --> 241         self.mixed_mass.mult(u, v)
#     242     return self.residual
#
# File /home/clustor2/ma/n/np923/firedrake/src/PyOP2/pyop2/utils.py:62, in cached_property.__get__(self, obj, cls)
#      60 if obj is None:
#      61     return self
# ---> 62 obj.__dict__[self.__name__] = result = self.fget(obj)
#      63 return result
#
# File /home/clustor2/ma/n/np923/firedrake/src/firedrake/firedrake/projection.py:235, in SupermeshProjector.mixed_mass(self)
#     232 @cached_property
#     233 def mixed_mass(self):
#     234     from firedrake.supermeshing import assemble_mixed_mass_matrix
# --> 235     return assemble_mixed_mass_matrix(self.source.function_space(),
#     236                                       self.target.function_space())
#
# File petsc4py/PETSc/Log.pyx:188, in petsc4py.PETSc.Log.EventDecorator.decorator.wrapped_func()
#
# File petsc4py/PETSc/Log.pyx:189, in petsc4py.PETSc.Log.EventDecorator.decorator.wrapped_func()
#
# File /home/clustor2/ma/n/np923/firedrake/src/firedrake/firedrake/supermeshing.py:76, in assemble_mixed_mass_matrix(V_A, V_B)
#      70     if V_A.ufl_element().mapping() != "identity" or V_B.ufl_element().mapping() != "identity":
#      71         msg = """
#      72 Sorry, only implemented for affine maps for now. To do non-affine, we'd need to
#      73 import much more of the assembly engine of UFL/TSFC/etc to do the assembly on
#      74 each supermesh cell.
#      75 """
# ---> 76         raise NotImplementedError(msg)
#      78     mesh_A = V_A.mesh()
#      79     mesh_B = V_B.mesh()
#
# NotImplementedError:
# Sorry, only implemented for affine maps for now. To do non-affine, we'd need to
# import much more of the assembly engine of UFL/TSFC/etc to do the assembly on
# each supermesh cell.

# %%
samples1 = torch.load("data/KS/samples/N4096_HER_nu0029_T01_samples1200.pt").unsqueeze(2).to(device=device)
samples2 = torch.load("data/KS/samples/N512_HER_nu0029_T01_samples1200.pt").unsqueeze(2).to(device=device)

with CheckpointFile(f"/home/clustor2/ma/n/np923/fem_neural_operator/playground/data/KS/meshes/N4096.h5", "r") as f:
    mesh1 = f.load_mesh()

with CheckpointFile(f"/home/clustor2/ma/n/np923/fem_neural_operator/playground/data/KS/meshes/N512.h5", "r") as f:
    mesh2 = f.load_mesh()

# %%
her1 = FunctionSpace(mesh1, "HER", 3)
her2 = FunctionSpace(mesh2, "HER", 3) 
cg1 = FunctionSpace(mesh1, "CG", 1)
cg2 = FunctionSpace(mesh2, "CG", 1)

func_her1 = Function(her1, val=samples1[index, 1, :].cpu().numpy())
func_her2 = Function(her2, val=samples2[index, 1, :].cpu().numpy())
func_cg2 = Function(cg2)
func_cg1 = Function(cg1)

func_cg1.interpolate(func_her1)
func_cg2.interpolate(func_her2)
# Out:
# Coefficient(WithGeometry(FunctionSpace(<firedrake.mesh.MeshTopology object at 0x7f0ba3caaf50>, FiniteElement('Lagrange', interval, 1), name=None), Mesh(VectorElement(FiniteElement('Discontinuous Lagrange', interval, 1, variant='equispaced'), dim=1, variant='equispaced'), 160)), 300)

# %%
fig, axes = plt.subplots()

plot(func_cg1, axes=axes, label="N4096")
plot(func_cg2, axes=axes, label="N512")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from firedrake import *
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from classes import *
from classes.Dataset import Dataset
device = torch.device("cuda:3") if torch.cuda.is_available() else torch.device("cpu")

# %%
N=4096

T_domain = ["01", "02", "03", "04", "05"]
epoches_losses = []
for T in T_domain:
    model = KSModel.load(f"../../data/KS/models/fourier/N{N}/T{T}/D64_M16_samples1000_epoch500.pt", N, T, device)
    data_path = f"../../data/KS/samples/N{N}_HER_nu0029_T{T}_samples1200.pt"
    
    samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
    grid = torch.linspace(0, model.L, model.dof_count, device=device)
    trainset = Dataset(torch.tensor(samples[:model.train_samples]), torch.tensor(grid))
    testset = Dataset(torch.tensor(samples[model.train_samples:]), torch.tensor(grid))
    
    mean_rel_l2_loss = lambda x, y: torch.mean(torch.norm(x - y, 2, dim=-1)/torch.norm(y, 2, dim=-1))
    
    optimizer = torch.optim.Adam(model.network.parameters(), lr=0.01)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 100, gamma=0.5)
    
    network_trainer = NeuralNetworkTrainer(
        model,
        trainset,
        testset,
        mean_rel_l2_loss,
        optimizer,
        scheduler,
        max_epoch=500
    )
    
    epoches_losses.append(network_trainer.test_epoch().detach().cpu().numpy())
        

plt.plot(T_domain, epoches_losses, label="500E Decay")
plt.legend()
plt.xlabel("T")
plt.ylabel("H1 Error")
plt.show()
print(epoches_losses)
# Out:
# /tmp/ipykernel_360187/2108742934.py:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   trainset = Dataset(torch.tensor(samples[:model.train_samples]), torch.tensor(grid))
# /tmp/ipykernel_360187/2108742934.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   testset = Dataset(torch.tensor(samples[model.train_samples:]), torch.tensor(grid))
# [array(0.00522725, dtype=float32), array(0.007314, dtype=float32), array(0.00787238, dtype=float32), array(0.00773769, dtype=float32), array(0.00901654, dtype=float32)]

# %%
N=2048

T_domain = ["01", "02", "03", "04", "05"]
epoches_losses = [[], []]
for i, epoches in enumerate([500, 600]):
    for T in T_domain:
        model = KSModel.load(f"data/KS/models/fourier/N2048/T{T}/D20_M8_samples1000_epoch{epoches}.pt",2048, T , device)
        data_path = f"data/KS/samples/N{N}_HER_nu0029_T{T}_samples1200.pt"
        
        samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
        grid = torch.linspace(0, model.L, model.dof_count, device=device)
        trainset = Dataset(torch.tensor(samples[:model.train_samples]), torch.tensor(grid))
        testset = Dataset(torch.tensor(samples[model.train_samples:]), torch.tensor(grid))
        
        mse_loss = nn.MSELoss(reduction="sum")
        loss = lambda x, y: mse_loss(x, y) / (N * len(x))  # Sum of differences, times step size, divide by batch size
        
        optimizer = torch.optim.Adam(model.network.parameters(), lr=0.01)
        scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 100, gamma=0.5)
        
        network_trainer = NeuralNetworkTrainer(
            model,
            trainset,
            testset,
            loss,
            optimizer,
            scheduler,
            max_epoch=500
        )
        
        epoches_losses[i].append(network_trainer.test_epoch().detach().cpu().numpy())
        

plt.plot(T_domain, epoches_losses[0], label="500E Decay")
plt.plot(T_domain, epoches_losses[1], label="600E Cyclic")
plt.legend()
plt.xlabel("T")
plt.ylabel("H1 Error")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 7
#       5 for i, epoches in enumerate([500, 600]):
#       6     for T in T_domain:
# ----> 7         model = KSModel.load(f"data/KS/models/fourier/N2048/T{T}/D20_M8_samples1000_epoch{epoches}.pt",2048, T , device)
#       8         data_path = f"data/KS/samples/N{N}_HER_nu0029_T{T}_samples1200.pt"
#      10         samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
#
# File /home/clustor2/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/NeuralOperatorModel.py:188, in KSModel.load(filename, N, T, device)
#     186 @staticmethod
#     187 def load(filename, N, T, device):
# --> 188     state_dict, config = torch.load(filename, map_location=device).values()
#     190     # with fd.CheckpointFile(f"/home/clustor2/ma/n/np923/fem_neural_operator/fem_neural_operator/data/KS/meshes/N{N}.h5", "r") as f:
#     191     #     mesh = f.load_mesh()
#     192
#     193
#     194     # projection = ProjectionCoefficient.load(mesh, equation_name, N, L, M, finite_element_space, "fourier", device=device)
#     197     model = KSModel(config["N"], config["M"], config["D"], config["depth"], T, config["projection_type"], config["finite_element_space"], device=device)
#
# File /home/clustor2/ma/n/np923/firedrake/lib/python3.10/site-packages/torch/serialization.py:997, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#     994 if 'encoding' not in pickle_load_args.keys():
#     995     pickle_load_args['encoding'] = 'utf-8'
# --> 997 with _open_file_like(f, 'rb') as opened_file:
#     998     if _is_zipfile(opened_file):
#     999         # The zipfile reader is going to advance the current file position.
#    1000         # If we want to actually tail call to torch.jit.load, we need to
#    1001         # reset back to the original position.
#    1002         orig_position = opened_file.tell()
#
# File /home/clustor2/ma/n/np923/firedrake/lib/python3.10/site-packages/torch/serialization.py:444, in _open_file_like(name_or_buffer, mode)
#     442 def _open_file_like(name_or_buffer, mode):
#     443     if _is_path(name_or_buffer):
# --> 444         return _open_file(name_or_buffer, mode)
#     445     else:
#     446         if 'w' in mode:
#
# File /home/clustor2/ma/n/np923/firedrake/lib/python3.10/site-packages/torch/serialization.py:425, in _open_file.__init__(self, name, mode)
#     424 def __init__(self, name, mode):
# --> 425     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/KS/models/fourier/N2048/T01/D20_M8_samples1000_epoch500.pt'

# %%
device = torch.device("cuda:3") if torch.cuda.is_available() else torch.device("cpu")

T_domain = ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12", "13", "14", "15"]
N_domain = [64, 128, 256, 512, 1024]
N_losses = [[], [], [], [], []]
for i, N in enumerate(N_domain):
    for T in T_domain:
        model = KSModel.load(f"../../data/KS/models/CG3/fourier/N{N}/T{T}/D64_M16_samples1000_epoch500.pt", N, T, device)
        data_path = f"../../data/KS/samples/N{N}_CG3_nu0029_T{T}_samples1200.pt"

        cg3 = fd.FunctionSpace(model.mesh, "CG", 3)
        x = fd.assemble(fd.interpolate(fd.SpatialCoordinate(self.mesh)[0], cg3))

        
        samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
        grid = torch.linspace(0, model.L, model.dof_count, device=device)
        trainset = Dataset(torch.tensor(samples[:model.train_samples]), torch.tensor(grid))
        testset = Dataset(torch.tensor(samples[model.train_samples:]), torch.tensor(grid))
        
        mean_rel_l2_loss = lambda x, y: torch.mean(torch.norm(x - y, 2, dim=-1)/torch.norm(y, 2, dim=-1))
        
        optimizer = torch.optim.Adam(model.network.parameters(), lr=0.01)
        scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 100, gamma=0.5)
        
        network_trainer = NeuralNetworkTrainer(
            model,
            trainset,
            testset,
            mean_rel_l2_loss,
            optimizer,
            scheduler,
            max_epoch=500
        )
        
        N_losses[i].append(network_trainer.test_epoch().detach().cpu().numpy())
# Out:
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/NeuralOperatorModel.py:203: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict, config = torch.load(filename, map_location=device).values()
# /home/clustor/ma/n/np923/fem_neural_operator/firedrake/lib/python3.10/site-packages/torch/cuda/__init__.py:654: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/ProjectionCoefficient.py:173: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path, map_location=device)
# /tmp/ipykernel_3957699/3498518245.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# /tmp/ipykernel_3957699/3498518245.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   trainset = Dataset(N, torch.tensor(samples[:model.train_samples]), torch.tensor(grid))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 13
#      11 samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
#      12 grid = torch.linspace(0, model.L, model.dof_count, device=device)
# ---> 13 trainset = Dataset(N, torch.tensor(samples[:model.train_samples]), torch.tensor(grid))
#      14 testset = Dataset(N, torch.tensor(samples[model.train_samples:]), torch.tensor(grid))
#      16 mean_rel_l2_loss = lambda x, y: torch.mean(torch.norm(x - y, 2, dim=-1)/torch.norm(y, 2, dim=-1))
#
# TypeError: Dataset.__init__() takes 3 positional arguments but 4 were given

# %%
for i, losses in enumerate(N_losses):
    plt.plot(T_domain, losses, label=f"N = {N_domain[i]}")
    
plt.legend()
plt.xlabel("T $[10 \, X \, dt]$")
plt.ylabel("RelH1")
plt.grid()
plt.title("KS RelH1 vs T for different meshes")
plt.savefig("KS RelH1 vs T for different meshes")

# %%
N = 4096
L = 10.
T = 0.5
nu = 0.029
dt = 0.01
samples = 600


with CheckpointFile(f"/home/clustor2/ma/n/np923/fem_neural_operator/fem_neural_operator/data/KS/meshes/N{N}.h5", "r") as f:
    mesh = f.load_mesh()
    
her = FunctionSpace(mesh, "HER", 3) 
fs_out = FunctionSpace(mesh, "CG", 1)

x = SpatialCoordinate(her)[0]

# %%
sin_her = Function(her).project(Constant(1))
sin_her.dat.data
# Out:
# array([ 1.00000000e+00, -2.19748446e-15,  1.00000000e+00, ...,
#        -6.39160420e-15,  1.00000000e+00, -4.28372051e-15])

# %%
# %matplotlib widget

fig, axes = plt.subplots()

plot(Function(fs_out).interpolate(sin_her), label="proj sin", axes=axes)
plot(Function(fs_out).interpolate(Constant(1)), label="real sin", axes=axes)

axes.grid()
axes.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
functions = torch.zeros((2 * self.M + 1, fs.dof_count), dtype=torch.float64)  # Zero mode and cos, sin for each mode

for i in range(self.M + 1):
    if i == 0:
        self.functions[i, :] = torch.tensor(fd.Function(function_space).interpolate(1).dat.data)
        continue

    self.functions[2 * i -1, :] = torch.tensor(fd.Function(function_space).interpolate(fd.sin(i * 2 * fd.pi * x)).dat.data)
    self.functions[2 * i, :] = torch.tensor(fd.Function(function_space).interpolate(fd.cos(i * 2 * fd.pi * x)).dat.data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 functions = torch.zeros((2 * self.M + 1, fs.dof_count), dtype=torch.float64)  # Zero mode and cos, sin for each mode
#       3 for i in range(self.M + 1):
#       4     if i == 0:
#
# NameError: name 'self' is not defined

# %%
device = torch.device("cuda:3") if torch.cuda.is_available() else torch.device("cpu")

model_filename = "/home/clustor2/ma/n/np923/fem_neural_operator/fem_neural_operator/data/KS/models/fourier/N64/T01/D20_M8_samples1000_epoch500.pt"
model = KSModel.load(model_filename, 64, "01", device)

# %%
with CheckpointFile(f"/home/clustor2/ma/n/np923/fem_neural_operator/fem_neural_operator/data/KS/meshes/N{64}.h5", "r") as f:
    mesh = f.load_mesh()
    
her = FunctionSpace(mesh, "HER", 3) 
fs_out = FunctionSpace(mesh, "CG", 3)

func = Function(her, val=model.network.projection.functions[3, :].detach().cpu().numpy())

# %%
plot(Function(fs_out).project(func))

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

T_domain = ["01", "02", "03", "04", "05"]
N_domain = [64, 128, 512, 1024, 2048, 4096]
N_losses = [[], [], [], [], [], []]
for i, N in enumerate(N_domain):
    for T in T_domain:
        model = KSModel.load(f"../../data/KS/models/fourier/N{N}/T{T}/D64_M16_samples1000_epoch500.pt", N, T, device)
        data_path = f"../../data/KS/samples/N{N}_HER_nu0029_T{T}_samples1200.pt"
        
        samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
        grid = torch.linspace(0, model.L, model.dof_count, device=device)
        trainset = Dataset(torch.tensor(samples[:model.train_samples]), torch.tensor(grid))
        testset = Dataset(torch.tensor(samples[model.train_samples:]), torch.tensor(grid))
        
        mean_rel_l2_loss = lambda x, y: torch.mean(torch.norm(x - y, 2, dim=-1)/torch.norm(y, 2, dim=-1))
        loss = lambda x, y: mse_loss(x, y) / (N * len(x))  # Sum of differences, times step size, divide by batch size
        
        optimizer = torch.optim.Adam(model.network.parameters(), lr=0.01)
        scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 100, gamma=0.5)
        
        network_trainer = NeuralNetworkTrainer(
            model,
            trainset,
            testset,
            mean_rel_l2_loss,
            optimizer,
            scheduler,
            max_epoch=500
        )
        
        N_losses[i].append(network_trainer.test_epoch().detach().cpu().numpy())

# %%
from classes import KSModel, Dataset
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
# Check this out, the error is extremely small for:
# N=64, T=08, i=138, predict=5.331821739534636e-06, truth=-4.889443647457229e-08
# N=128, T=15, i=33, predict=-4.561152311027174e-06, truth=2.5902409178449334e-07
# N=512, T=01, i=160, predict=2.532033042158633e-07, truth=5.6315907747195814e-08
# N=2048, T=07, i=134, predict=-3.0340742026935653e-07, truth=-4.09238327161094e-08


T_domain = ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12", "13", "14", "15"]
N_domain = [64, 128, 512, 1024, 2048]

prediction_integrals = []
for N in N_domain:        
    
    for T in T_domain:
        model = KSModel.load(f"../../data/KS/models/CG3/fourier/N{N}/T{T}/D64_M16_samples1000_epoch500.pt", N, T, device)
        data_path = f"../../data/KS/samples/N{N}_CG3_nu0029_T{T}_samples1200.pt"
        samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
        
        cg3 = FunctionSpace(model.mesh, "CG", 3) 
        x = assemble(interpolate(SpatialCoordinate(model.mesh)[0], cg3))
        grid = torch.tensor(sorted(x.dat.data[:])).to(device=device, dtype=torch.float32)
        
        testset = Dataset(torch.tensor(samples[model.train_samples:]), torch.tensor(grid))
        
        with torch.no_grad():
            predictions = model.network(testset.inputs).detach().cpu().numpy()

        # prediction_integrals = []
        for i in range(200):
            f_predict = Function(cg3, val=predictions[i, 0, :])
            f_truth = Function(cg3, val=testset.targets[i, 0, :].detach().cpu().numpy())
            integral_predict = assemble(f_predict * dx)
            integral_truth = assemble(f_truth * dx)

            prediction_integrals.append(integral_predict)
            
            if (abs(integral_predict) < 10E-05):            
                print(f"N={N}, T={T}, i={i}, predict={integral_predict}, truth={integral_truth}")
        
            prediction_integrals.append(integral_predict)
# Out:
# /tmp/ipykernel_945569/3042362258.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# /tmp/ipykernel_945569/3042362258.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   testset = Dataset(torch.tensor(samples[model.train_samples:]), torch.tensor(grid))
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/NeuralOperatorModel.py:203: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict, config = torch.load(filename, map_location=device).values()
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/ProjectionCoefficient.py:173: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path, map_location=device)
# /tmp/ipykernel_945569/3042362258.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# /home/clustor/ma/n/np923/fem_neural_operator/firedrake/src/firedrake/firedrake/interpolation.py:385: FutureWarning: The use of `interpolate` to perform the numerical interpolation is deprecated.
# This feature will be removed very shortly.
#
# Instead, import `interpolate` from the `firedrake.__future__` module to update
# the interpolation's behaviour to return the symbolic `ufl.Interpolate` object associated
# with this interpolation.
#
# You can then assemble the resulting object to get the interpolated quantity
# of interest. For example,
#
# ```
# from firedrake.__future__ import interpolate
# ...
#
# assemble(interpolate(expr, V))
# ```
#
# Alternatively, you can also perform other symbolic operations on the interpolation operator, such as taking
# the derivative, and then assemble the resulting form.
#
#   warnings.warn("""The use of `interpolate` to perform the numerical interpolation is deprecated.
# /tmp/ipykernel_945569/3042362258.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   testset = Dataset(torch.tensor(samples[model.train_samples:]), torch.tensor(grid))
# N=64, T=05, i=92, predict=-2.8965878292208562e-05, truth=7.741620261556534e-08
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/ProjectionCoefficient.py:173: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path, map_location=device)
# /tmp/ipykernel_945569/3042362258.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# /home/clustor/ma/n/np923/fem_neural_operator/firedrake/src/firedrake/firedrake/interpolation.py:385: FutureWarning: The use of `interpolate` to perform the numerical interpolation is deprecated.
# This feature will be removed very shortly.
#
# Instead, import `interpolate` from the `firedrake.__future__` module to update
# the interpolation's behaviour to return the symbolic `ufl.Interpolate` object associated
# with this interpolation.
#
# You can then assemble the resulting object to get the interpolated quantity
# of interest. For example,
#
# ```
# from firedrake.__future__ import interpolate
# ...
#
# assemble(interpolate(expr, V))
# ```
#
# Alternatively, you can also perform other symbolic operations on the interpolation operator, such as taking
# the derivative, and then assemble the resulting form.
#
#   warnings.warn("""The use of `interpolate` to perform the numerical interpolation is deprecated.
# /tmp/ipykernel_945569/3042362258.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   testset = Dataset(torch.tensor(samples[model.train_samples:]), torch.tensor(grid))
# N=64, T=07, i=130, predict=-7.665240751342391e-05, truth=-9.36173446552174e-08
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/NeuralOperatorModel.py:203: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict, config = torch.load(filename, map_location=device).values()
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/ProjectionCoefficient.py:173: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path, map_location=device)
# /tmp/ipykernel_945569/3042362258.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# N=64, T=13, i=54, predict=6.333594988642215e-05, truth=-2.0198056002509315e-07
# N=64, T=13, i=91, predict=6.117140098004454e-05, truth=2.412222475431223e-07
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/ProjectionCoefficient.py:173: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path, map_location=device)
# /tmp/ipykernel_945569/3042362258.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# /home/clustor/ma/n/np923/fem_neural_operator/firedrake/src/firedrake/firedrake/interpolation.py:385: FutureWarning: The use of `interpolate` to perform the numerical interpolation is deprecated.
# This feature will be removed very shortly.
#
# Instead, import `interpolate` from the `firedrake.__future__` module to update
# the interpolation's behaviour to return the symbolic `ufl.Interpolate` object associated
# with this interpolation.
#
# You can then assemble the resulting object to get the interpolated quantity
# of interest. For example,
#
# ```
# from firedrake.__future__ import interpolate
# ...
#
# assemble(interpolate(expr, V))
# ```
#
# Alternatively, you can also perform other symbolic operations on the interpolation operator, such as taking
# the derivative, and then assemble the resulting form.
#
#   warnings.warn("""The use of `interpolate` to perform the numerical interpolation is deprecated.
# /tmp/ipykernel_945569/3042362258.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   testset = Dataset(torch.tensor(samples[model.train_samples:]), torch.tensor(grid))
# N=64, T=14, i=138, predict=4.010861931802508e-05, truth=-3.948421217585026e-08
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/NeuralOperatorModel.py:203: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict, config = torch.load(filename, map_location=device).values()
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/ProjectionCoefficient.py:173: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path, map_location=device)
# /tmp/ipykernel_945569/3042362258.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# N=128, T=01, i=88, predict=3.061897586699926e-05, truth=2.4022784558003045e-08
# N=128, T=05, i=44, predict=-1.7175261744213134e-05, truth=1.9806976449024352e-07
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/ProjectionCoefficient.py:173: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path, map_location=device)
# /tmp/ipykernel_945569/3042362258.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# /home/clustor/ma/n/np923/fem_neural_operator/firedrake/src/firedrake/firedrake/interpolation.py:385: FutureWarning: The use of `interpolate` to perform the numerical interpolation is deprecated.
# This feature will be removed very shortly.
#
# Instead, import `interpolate` from the `firedrake.__future__` module to update
# the interpolation's behaviour to return the symbolic `ufl.Interpolate` object associated
# with this interpolation.
#
# You can then assemble the resulting object to get the interpolated quantity
# of interest. For example,
#
# ```
# from firedrake.__future__ import interpolate
# ...
#
# assemble(interpolate(expr, V))
# ```
#
# Alternatively, you can also perform other symbolic operations on the interpolation operator, such as taking
# the derivative, and then assemble the resulting form.
#
#   warnings.warn("""The use of `interpolate` to perform the numerical interpolation is deprecated.
# /tmp/ipykernel_945569/3042362258.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   testset = Dataset(torch.tensor(samples[model.train_samples:]), torch.tensor(grid))
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/NeuralOperatorModel.py:203: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict, config = torch.load(filename, map_location=device).values()
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/ProjectionCoefficient.py:173: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path, map_location=device)
# /tmp/ipykernel_945569/3042362258.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/ProjectionCoefficient.py:173: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path, map_location=device)
# /tmp/ipykernel_945569/3042362258.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# /home/clustor/ma/n/np923/fem_neural_operator/firedrake/src/firedrake/firedrake/interpolation.py:385: FutureWarning: The use of `interpolate` to perform the numerical interpolation is deprecated.
# This feature will be removed very shortly.
#
# Instead, import `interpolate` from the `firedrake.__future__` module to update
# the interpolation's behaviour to return the symbolic `ufl.Interpolate` object associated
# with this interpolation.
#
# You can then assemble the resulting object to get the interpolated quantity
# of interest. For example,
#
# ```
# from firedrake.__future__ import interpolate
# ...
#
# assemble(interpolate(expr, V))
# ```
#
# Alternatively, you can also perform other symbolic operations on the interpolation operator, such as taking
# the derivative, and then assemble the resulting form.
#
#   warnings.warn("""The use of `interpolate` to perform the numerical interpolation is deprecated.
# /tmp/ipykernel_945569/3042362258.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   testset = Dataset(torch.tensor(samples[model.train_samples:]), torch.tensor(grid))
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/NeuralOperatorModel.py:203: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict, config = torch.load(filename, map_location=device).values()
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/ProjectionCoefficient.py:173: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path, map_location=device)
# /tmp/ipykernel_945569/3042362258.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# N=128, T=14, i=165, predict=8.928608924111681e-05, truth=-2.747432088971524e-07
# N=512, T=01, i=11, predict=4.634633570072552e-05, truth=-8.542420186419797e-09
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/ProjectionCoefficient.py:173: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path, map_location=device)
# /tmp/ipykernel_945569/3042362258.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# /home/clustor/ma/n/np923/fem_neural_operator/firedrake/src/firedrake/firedrake/interpolation.py:385: FutureWarning: The use of `interpolate` to perform the numerical interpolation is deprecated.
# This feature will be removed very shortly.
#
# Instead, import `interpolate` from the `firedrake.__future__` module to update
# the interpolation's behaviour to return the symbolic `ufl.Interpolate` object associated
# with this interpolation.
#
# You can then assemble the resulting object to get the interpolated quantity
# of interest. For example,
#
# ```
# from firedrake.__future__ import interpolate
# ...
#
# assemble(interpolate(expr, V))
# ```
#
# Alternatively, you can also perform other symbolic operations on the interpolation operator, such as taking
# the derivative, and then assemble the resulting form.
#
#   warnings.warn("""The use of `interpolate` to perform the numerical interpolation is deprecated.
# /tmp/ipykernel_945569/3042362258.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   testset = Dataset(torch.tensor(samples[model.train_samples:]), torch.tensor(grid))
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/NeuralOperatorModel.py:203: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict, config = torch.load(filename, map_location=device).values()
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/ProjectionCoefficient.py:173: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path, map_location=device)
# /tmp/ipykernel_945569/3042362258.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# N=512, T=08, i=43, predict=-3.779205145719798e-05, truth=1.2232552412748915e-07
# N=512, T=11, i=44, predict=-9.83144006111759e-05, truth=-3.927045108104198e-08
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/ProjectionCoefficient.py:173: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path, map_location=device)
# /tmp/ipykernel_945569/3042362258.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# /home/clustor/ma/n/np923/fem_neural_operator/firedrake/src/firedrake/firedrake/interpolation.py:385: FutureWarning: The use of `interpolate` to perform the numerical interpolation is deprecated.
# This feature will be removed very shortly.
#
# Instead, import `interpolate` from the `firedrake.__future__` module to update
# the interpolation's behaviour to return the symbolic `ufl.Interpolate` object associated
# with this interpolation.
#
# You can then assemble the resulting object to get the interpolated quantity
# of interest. For example,
#
# ```
# from firedrake.__future__ import interpolate
# ...
#
# assemble(interpolate(expr, V))
# ```
#
# Alternatively, you can also perform other symbolic operations on the interpolation operator, such as taking
# the derivative, and then assemble the resulting form.
#
#   warnings.warn("""The use of `interpolate` to perform the numerical interpolation is deprecated.
# /tmp/ipykernel_945569/3042362258.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   testset = Dataset(torch.tensor(samples[model.train_samples:]), torch.tensor(grid))
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/NeuralOperatorModel.py:203: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict, config = torch.load(filename, map_location=device).values()
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/ProjectionCoefficient.py:173: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path, map_location=device)
# /tmp/ipykernel_945569/3042362258.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# N=512, T=15, i=141, predict=7.260816347143621e-05, truth=-4.026023431891264e-09
# N=512, T=15, i=192, predict=2.689145411333357e-06, truth=-2.3605948380972265e-08
# N=1024, T=01, i=36, predict=-2.4427220833157088e-05, truth=-4.394072400135769e-08
# N=1024, T=01, i=74, predict=4.746143532145474e-05, truth=3.850649925669666e-08
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/ProjectionCoefficient.py:173: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path, map_location=device)
# /tmp/ipykernel_945569/3042362258.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# /home/clustor/ma/n/np923/fem_neural_operator/firedrake/src/firedrake/firedrake/interpolation.py:385: FutureWarning: The use of `interpolate` to perform the numerical interpolation is deprecated.
# This feature will be removed very shortly.
#
# Instead, import `interpolate` from the `firedrake.__future__` module to update
# the interpolation's behaviour to return the symbolic `ufl.Interpolate` object associated
# with this interpolation.
#
# You can then assemble the resulting object to get the interpolated quantity
# of interest. For example,
#
# ```
# from firedrake.__future__ import interpolate
# ...
#
# assemble(interpolate(expr, V))
# ```
#
# Alternatively, you can also perform other symbolic operations on the interpolation operator, such as taking
# the derivative, and then assemble the resulting form.
#
#   warnings.warn("""The use of `interpolate` to perform the numerical interpolation is deprecated.
# /tmp/ipykernel_945569/3042362258.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   testset = Dataset(torch.tensor(samples[model.train_samples:]), torch.tensor(grid))
# ...
#   state_dict, config = torch.load(filename, map_location=device).values()
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/ProjectionCoefficient.py:173: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path, map_location=device)
# /tmp/ipykernel_945569/3042362258.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# N=1024, T=13, i=129, predict=-6.805434777098814e-05, truth=-4.002706582640748e-08
# N=1024, T=13, i=131, predict=-2.8000131354643664e-05, truth=-8.754152770137206e-08
# N=1024, T=14, i=13, predict=5.506365975592125e-05, truth=-4.5395535755611085e-08
# N=1024, T=15, i=43, predict=6.974471032166569e-05, truth=-1.3761427588091068e-08
# N=2048, T=02, i=71, predict=-6.869183090613379e-06, truth=-3.5154346332965074e-08
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/ProjectionCoefficient.py:173: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path, map_location=device)
# /tmp/ipykernel_945569/3042362258.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# /home/clustor/ma/n/np923/fem_neural_operator/firedrake/src/firedrake/firedrake/interpolation.py:385: FutureWarning: The use of `interpolate` to perform the numerical interpolation is deprecated.
# This feature will be removed very shortly.
#
# Instead, import `interpolate` from the `firedrake.__future__` module to update
# the interpolation's behaviour to return the symbolic `ufl.Interpolate` object associated
# with this interpolation.
#
# You can then assemble the resulting object to get the interpolated quantity
# of interest. For example,
#
# ```
# from firedrake.__future__ import interpolate
# ...
#
# assemble(interpolate(expr, V))
# ```
#
# Alternatively, you can also perform other symbolic operations on the interpolation operator, such as taking
# the derivative, and then assemble the resulting form.
#
#   warnings.warn("""The use of `interpolate` to perform the numerical interpolation is deprecated.
# /tmp/ipykernel_945569/3042362258.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   testset = Dataset(torch.tensor(samples[model.train_samples:]), torch.tensor(grid))
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/NeuralOperatorModel.py:203: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict, config = torch.load(filename, map_location=device).values()
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/ProjectionCoefficient.py:173: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path, map_location=device)
# /tmp/ipykernel_945569/3042362258.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# N=2048, T=09, i=179, predict=6.476998957160852e-05, truth=2.1177747011054906e-08
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/ProjectionCoefficient.py:173: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path, map_location=device)
# /tmp/ipykernel_945569/3042362258.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# /home/clustor/ma/n/np923/fem_neural_operator/firedrake/src/firedrake/firedrake/interpolation.py:385: FutureWarning: The use of `interpolate` to perform the numerical interpolation is deprecated.
# This feature will be removed very shortly.
#
# Instead, import `interpolate` from the `firedrake.__future__` module to update
# the interpolation's behaviour to return the symbolic `ufl.Interpolate` object associated
# with this interpolation.
#
# You can then assemble the resulting object to get the interpolated quantity
# of interest. For example,
#
# ```
# from firedrake.__future__ import interpolate
# ...
#
# assemble(interpolate(expr, V))
# ```
#
# Alternatively, you can also perform other symbolic operations on the interpolation operator, such as taking
# the derivative, and then assemble the resulting form.
#
#   warnings.warn("""The use of `interpolate` to perform the numerical interpolation is deprecated.
# /tmp/ipykernel_945569/3042362258.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   testset = Dataset(torch.tensor(samples[model.train_samples:]), torch.tensor(grid))
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/NeuralOperatorModel.py:203: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict, config = torch.load(filename, map_location=device).values()
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/ProjectionCoefficient.py:173: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path, map_location=device)
# /tmp/ipykernel_945569/3042362258.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# N=2048, T=12, i=43, predict=-9.572920438947457e-05, truth=-1.748230008885485e-08
# N=2048, T=12, i=199, predict=-1.0387113120391462e-05, truth=-5.47533739188807e-10

# %%
plt.hist(np.abs(prediction_integrals), bins=[10**i for i in [-8, -7, -6, -5, -4, -3, -2, -1 ,0, 1]])
plt.xscale("log")
plt.yscale("log")
plt.ylabel("Count")
plt.xlabel("Value of integral")
plt.title("Integral values histogram for KS predictions")
plt.savefig("KS integral values histogram")

# %%
# T = "01"
# N = 1024
# i = 36

N, T, i =1024, 13, 150
compositions = 30

model = KSModel.load(f"../../data/KS/models/CG3/fourier/N{N}/T{T}/D64_M16_samples1000_epoch500.pt", N, T, device)


data_path = f"../../data/KS/samples/N{N}_CG3_nu0029_T{T}_samples1200.pt"

samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
cg3 = FunctionSpace(model.mesh, "CG", 3) 
x = assemble(interpolate(SpatialCoordinate(model.mesh)[0], cg3))
grid = torch.tensor(sorted(x.dat.data[:])).to(device=device, dtype=torch.float32)

testset = Dataset(torch.tensor(samples[1000:]), torch.tensor(grid))

integrals = []
with torch.no_grad():
    for _ in range(compositions):
        testset.inputs[:, 0, :] = model.network(testset.inputs)[:, 0, :]
        # for i in range(200):
        f_predict = Function(cg3, val=testset.inputs[i, 0, :].detach().cpu().numpy())
        integrals.append(abs(assemble(f_predict * dx)))

        # integral_means.append(np.mean(np.abs(integrals)))
# Out:
# /tmp/ipykernel_945569/967404208.py:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# /tmp/ipykernel_945569/967404208.py:18: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   testset = Dataset(torch.tensor(samples[1000:]), torch.tensor(grid))

# %%
plt.plot(integrals)
plt.yscale("log")

# %%
plt.plot(list(range(compositions)), integrals)
plt.grid()
plt.yscale("log")

# %%
integrals
# Out:
# [np.float64(4.773028194141431e-05),
#  np.float64(0.6549679883755761),
#  np.float64(2.2340012807399052),
#  np.float64(2.3314783885143706),
#  np.float64(3.949016248807313),
#  np.float64(4.493457684293388),
#  np.float64(4.64868993498385),
#  np.float64(4.624622657429427),
#  np.float64(4.6169223194010565),
#  np.float64(4.611917082220317)]

# %% [markdown]
# # H1 Norm discrepancy

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

N = 1024
L = 10
h = L/N

mesh = PeriodicIntervalMesh(ncells=N, length=L)
x = SpatialCoordinate(mesh)[0]
her = FunctionSpace(mesh, "HER", 3) 

sin_func = Function(her)
sin_func.project(sin(2 * pi *x /L))

cos_func = Function(her)
cos_func.project(cos(2 * pi *x /L))

# diff_func = Function(her, val=sin_func.dat.data - cos_func.dat.data)
# Out:
# Coefficient(WithGeometry(FunctionSpace(<firedrake.mesh.MeshTopology object at 0x787d66f675e0>, FiniteElement('Hermite', interval, 3), name=None), Mesh(VectorElement(FiniteElement('Discontinuous Lagrange', interval, 1, variant='equispaced'), dim=1, variant='equispaced'), 27)), 36)

# %%
fd_L2_norm = norm(sin_func, "L2")
fd_H1_norm = norm(sin_func, "H1")
coeff_norm = np.sqrt(h * np.sum(sin_func.dat.data ** 2))

# %%
print(f"Firedrake L2: {fd_L2_norm}")
print(f"Firedrake H1: {fd_H1_norm}")
print(f"Riemann sum (H1): {coeff_norm}")
# Out:
# Firedrake L2: 2.236067977499789
# Firedrake H1: 2.640818221729368
# Riemann sum (H1): 2.236110070587828

# %%
# sin_func.dat.data[0::4] gives the left point-evaluation
# sin_func.dat.data[1::4] gives the left derivative point-evaluation
# sin_func.dat.data[2::4] gives the right point-evaluation
# sin_func.dat.data[3::4] gives the right derivative point-evaluation

pullback_ratio = 1/h
coeff_norm = h ** 0.5 * np.sqrt(np.sum(sin_func.dat.data[0::4] ** 2) + \
             np.sum((pullback_ratio * sin_func.dat.data[1::4]) ** 2) + \
             np.sum(sin_func.dat.data[2::4] ** 2) + \
             np.sum((pullback_ratio*sin_func.dat.data[3::4]) ** 2))

coeff_norm - fd_H1_norm
# Out:
# 1.6908696665041134e-11

# %%
from classes import KSModel, Dataset

N = 512
L = 10
h = L/N

model = KSModel.load(f"../../data/KS/models/fourier/N{N}/T01/D64_M16_samples1000_epoch500.pt", N, "01", device)

data_path = f"../../data/KS/samples/N{N}_HER_nu0029_T01_samples1200.pt"
samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)

grid = torch.linspace(0, model.L, model.dof_count, device=device)
testset = Dataset(torch.tensor(samples[model.train_samples:]), torch.tensor(grid))

with CheckpointFile(f"../../data/KS/meshes/N{N}.h5", "r") as f:
    mesh = f.load_mesh()

her = FunctionSpace(mesh, "HER", 3)
# Out:
# /tmp/ipykernel_19056/3597045910.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   testset = Dataset(torch.tensor(samples[model.train_samples:]), torch.tensor(grid))

# %%
with torch.no_grad():
    predictions = model.network(testset.inputs)

# %%
i = 66
coeffs_predict = predictions[i, 0, :].to(dtype=torch.float64, device="cpu").numpy()
coeffs_target = testset.targets[i, 0, :].to(dtype=torch.float64, device="cpu").numpy()
coeffs = coeffs_target - coeffs_predict

fd_errornorm = errornorm(Function(her, val=coeffs_predict), Function(her, val=coeffs_target), "H1")
fd_norm = norm(Function(her, val=coeffs_predict), "H1")


pullback_ratio = 1/h

coeff_errornorm = h ** 0.5 * np.sqrt(np.sum(coeffs[0::4] ** 2) + \
             np.sum((pullback_ratio * coeffs[1::4]) ** 2) + \
             np.sum(coeffs[2::4] ** 2) + \
             np.sum((pullback_ratio*coeffs[3::4]) ** 2))

coeff_norm = h ** 0.5 * np.sqrt(np.sum(coeffs_predict[0::4] ** 2) + \
             np.sum((pullback_ratio * coeffs_predict[1::4]) ** 2) + \
             np.sum(coeffs_predict[2::4] ** 2) + \
             np.sum((pullback_ratio * coeffs_predict[3::4]) ** 2))


print(f"Firedrake H1 norm: {fd_norm:.5}, Coefficient H1 norm: {coeff_norm:.5}")
print()
print(f"Firedrake H1 errornorm: {fd_errornorm:.5}, Coefficient H1 errornorm: {coeff_errornorm:.5}")
# Out:
# Firedrake H1 norm: 119.41, Coefficient H1 norm: 118.97
#
# Firedrake H1 errornorm: 5.5438, Coefficient H1 errornorm: 2.6413

# %%
norms = []
for i in range(len(testset)):
    func_in = Function(her, val = testset.targets[i, 0, :].cpu().numpy())
    predict = Function(her, val = predictions[i, 0, :].cpu().numpy())
    norms.append(errornorm(futnc_in, predict, "H1")/norm(func_in, "H1"))

np.mean(norms)
# Out:
# 0.056031836394246734

# %%
h = 10/N

testset.targets[:, 0, 1::4] *= 1/h
testset.targets[:, 0, 3::4] *= 1/h

predictions[:, 0, 1::4] *= 1/h
predictions[:, 0, 3::4] *= 1/h


# h**0.5 * np.linalg.norm(coeffs)
# np.sqrt(h * np.sum(coeffs[0::4] ** 2) + \
#              h * np.sum((1/h * coeffs[1::4]) ** 2) + \
#              h * np.sum(coeffs[2::4] ** 2) + \
#              h * np.sum((1/h*coeffs[3::4]) ** 2))

# %%
mean_rel_l2_loss = lambda x, y: torch.mean(torch.norm(x - y, 2, dim=-1) / torch.norm(y, 2, dim=-1))
mean_rel_l2_loss(predictions, testset.targets)
# Out:
# tensor(0.0252, device='cuda:0')

# %%
np.sqrt(h * np.sum(sin_func.dat.data **2) + h * np.sum(sin_func.dx().dat.data **2))
# Out:
# 31.780646728982106

# %%
dfdx = Function(her)
dfdx.project(sin_func.dx(0))
np.sqrt(h * np.sum(sin_func.dat.data **2) + h * np.sum(dfdx.dat.data **2))
# Out:
# 26.540019568027038

# %%
for i, val in enumerate(Function(her).project(Constant(1)).dat.data):
    if val < 10**(-12) and i % 2 != 1:
        print("ahahahahha")

# %% [markdown]
# # Composing

# %%
def composition_losses(N):
    T1 = "01"
    T2_domain = ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12", "13", "14", "15"]
    
    model = KSModel.load(f"../../data/KS/models/fourier/N{N}/T{T1}/D64_M16_samples1000_epoch500.pt", N, T1, device)
    
    losses = []
    for T2 in T2_domain:
        data_path = f"../../data/KS/samples/N{N}_HER_nu0029_T{T2}_samples1200.pt"
        
        samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
        grid = torch.linspace(0, 10, 2 * N, device=device)
        testset = KSDataset(N, torch.tensor(samples[1000:]), torch.tensor(grid))
        
        
        mean_rel_l2_loss = lambda x, y: torch.mean(torch.norm(x - y, 2, dim=-1) / torch.norm(y, 2, dim=-1))
        
        with torch.no_grad():
            for _ in range(int(T2) - 1):
                testset.inputs[:, 0, :] = model.network(testset.inputs)[:, 0, :]
            
            losses.append(mean_rel_l2_loss(model.network(testset.inputs), testset.targets).cpu().numpy())
    
    return losses

# %%
N_domain = [64, 128, 512, 1024, 2048, 4096]
T2_domain = ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12", "13", "14", "15"]

plt.figure(figsize=(7, 4.5))
for N in N_domain:
    plt.plot(T2_domain, composition_losses(N), label=f"N={N} model")
    
plt.legend()
plt.grid()
plt.yscale("log")
# Out:
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/ProjectionCoefficient.py:173: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path, map_location=device)
# /tmp/ipykernel_1748482/861640036.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# /tmp/ipykernel_1748482/861640036.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   testset = KSDataset(N, torch.tensor(samples[1000:]), torch.tensor(grid))
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/NeuralOperatorModel.py:195: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict, config = torch.load(filename, map_location=device).values()
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/ProjectionCoefficient.py:173: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path, map_location=device)
# /tmp/ipykernel_1748482/861640036.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# /tmp/ipykernel_1748482/861640036.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   testset = KSDataset(N, torch.tensor(samples[1000:]), torch.tensor(grid))
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/NeuralOperatorModel.py:195: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict, config = torch.load(filename, map_location=device).values()
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/ProjectionCoefficient.py:173: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path, map_location=device)
# /tmp/ipykernel_1748482/861640036.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# /tmp/ipykernel_1748482/861640036.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   testset = KSDataset(N, torch.tensor(samples[1000:]), torch.tensor(grid))
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/NeuralOperatorModel.py:195: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict, config = torch.load(filename, map_location=device).values()

# %%
N = 64
T = "05"
with CheckpointFile(f"../../data/KS/meshes/N{N}.h5", "r") as f:
    mesh = f.load_mesh()
    
cg3 = FunctionSpace(mesh, "CG", 3) 


data_path = f"../../data/KS/samples/N{N}_CG3_nu0029_T{T}_samples1200.pt"

samples = torch.load(data_path).to(dtype=torch.float32)
# Out:
# /tmp/ipykernel_3957699/441441851.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).to(dtype=torch.float32)

# %%
from firedrake.__future__ import interpolate

x = assemble(interpolate(SpatialCoordinate(mesh)[0], cg3))

# Get the node locations
node_locations = torch.tensor(sorted(x.dat.data[:]))

# Print the node locations
print(node_locations)
# Out:
# tensor([ 0.0432,  0.1131,  0.1562,  0.1994,  0.2693,  0.3125,  0.3557,  0.4256,
#          0.4688,  0.5119,  0.5818,  0.6250,  0.6682,  0.7381,  0.7812,  0.8244,
#          0.8943,  0.9375,  0.9807,  1.0506,  1.0938,  1.1369,  1.2068,  1.2500,
#          1.2932,  1.3631,  1.4063,  1.4494,  1.5193,  1.5625,  1.6057,  1.6756,
#          1.7188,  1.7619,  1.8318,  1.8750,  1.9182,  1.9881,  2.0313,  2.0744,
#          2.1443,  2.1875,  2.2307,  2.3006,  2.3438,  2.3869,  2.4568,  2.5000,
#          2.5432,  2.6131,  2.6562,  2.6994,  2.7693,  2.8125,  2.8557,  2.9256,
#          2.9688,  3.0119,  3.0818,  3.1250,  3.1682,  3.2381,  3.2812,  3.3244,
#          3.3943,  3.4375,  3.4807,  3.5506,  3.5938,  3.6369,  3.7068,  3.7500,
#          3.7932,  3.8631,  3.9062,  3.9494,  4.0193,  4.0625,  4.1057,  4.1756,
#          4.2188,  4.2619,  4.3318,  4.3750,  4.4182,  4.4881,  4.5313,  4.5744,
#          4.6443,  4.6875,  4.7307,  4.8006,  4.8438,  4.8869,  4.9568,  5.0000,
#          5.0432,  5.1131,  5.1562,  5.1994,  5.2693,  5.3125,  5.3557,  5.4256,
#          5.4687,  5.5119,  5.5818,  5.6250,  5.6682,  5.7381,  5.7812,  5.8244,
#          5.8943,  5.9375,  5.9807,  6.0506,  6.0937,  6.1369,  6.2068,  6.2500,
#          6.2932,  6.3631,  6.4062,  6.4494,  6.5193,  6.5625,  6.6057,  6.6756,
#          6.7188,  6.7619,  6.8318,  6.8750,  6.9182,  6.9881,  7.0312,  7.0744,
#          7.1443,  7.1875,  7.2307,  7.3006,  7.3438,  7.3869,  7.4568,  7.5000,
#          7.5432,  7.6131,  7.6562,  7.6994,  7.7693,  7.8125,  7.8557,  7.9256,
#          7.9688,  8.0119,  8.0818,  8.1250,  8.1682,  8.2381,  8.2812,  8.3244,
#          8.3943,  8.4375,  8.4807,  8.5506,  8.5938,  8.6369,  8.7068,  8.7500,
#          8.7932,  8.8631,  8.9062,  8.9494,  9.0193,  9.0625,  9.1057,  9.1756,
#          9.2188,  9.2619,  9.3318,  9.3750,  9.4182,  9.4881,  9.5312,  9.5744,
#          9.6443,  9.6875,  9.7307,  9.8006,  9.8438,  9.8869,  9.9568, 10.0000],
#        dtype=torch.float64)

# %%
# Out:
# np.float64(0.15625)

# %%
device = torch.device("cuda:0") if torch.cuda.is_available() else torch.device("cpu")
M, D, depth = 16, 64, 4
N, T = 128, "01"

model = KSModel(N, M, D, depth, T, "fourier", "CG3", device=device)
losses = model.train(f"../../data/KS/samples/N{N}_CG3_nu0029_T{T}_samples1200.pt", 750, device=device)
# Out:
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/ProjectionCoefficient.py:173: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path, map_location=device)
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/NeuralOperatorModel.py:54: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# /home/clustor/ma/n/np923/fem_neural_operator/firedrake/src/firedrake/firedrake/interpolation.py:385: FutureWarning: The use of `interpolate` to perform the numerical interpolation is deprecated.
# This feature will be removed very shortly.
#
# Instead, import `interpolate` from the `firedrake.__future__` module to update
# the interpolation's behaviour to return the symbolic `ufl.Interpolate` object associated
# with this interpolation.
#
# You can then assemble the resulting object to get the interpolated quantity
# of interest. For example,
#
# ```
# from firedrake.__future__ import interpolate
# ...
#
# assemble(interpolate(expr, V))
# ```
#
# Alternatively, you can also perform other symbolic operations on the interpolation operator, such as taking
# the derivative, and then assemble the resulting form.
#
#   warnings.warn("""The use of `interpolate` to perform the numerical interpolation is deprecated.
# Epoch: 1 | Train Loss: 0.4021 | Test Loss: 0.4177 | lr: 0.01
# Epoch: 2 | Train Loss: 0.2433 | Test Loss: 0.2652 | lr: 0.01
# Epoch: 3 | Train Loss: 0.1752 | Test Loss: 0.1937 | lr: 0.01
# Epoch: 4 | Train Loss: 0.1762 | Test Loss: 0.1918 | lr: 0.01
# Epoch: 5 | Train Loss: 0.1534 | Test Loss: 0.1682 | lr: 0.01
# Epoch: 6 | Train Loss: 0.1511 | Test Loss: 0.1635 | lr: 0.01
# Epoch: 7 | Train Loss: 0.1221 | Test Loss: 0.1367 | lr: 0.01
# Epoch: 8 | Train Loss: 0.1079 | Test Loss: 0.1173 | lr: 0.01
# Epoch: 9 | Train Loss: 0.1187 | Test Loss: 0.1277 | lr: 0.01
# Epoch: 10 | Train Loss: 0.11 | Test Loss: 0.1179 | lr: 0.01
# Epoch: 11 | Train Loss: 0.08141 | Test Loss: 0.09091 | lr: 0.01
# Epoch: 12 | Train Loss: 0.0965 | Test Loss: 0.1055 | lr: 0.01
# Epoch: 13 | Train Loss: 0.08834 | Test Loss: 0.09634 | lr: 0.01
# Epoch: 726 | Train Loss: 0.002819 | Test Loss: 0.00359 | lr: 7.8125e-05
# Epoch: 727 | Train Loss: 0.002821 | Test Loss: 0.003591 | lr: 7.8125e-05
# Epoch: 728 | Train Loss: 0.002818 | Test Loss: 0.003589 | lr: 7.8125e-05
# Epoch: 729 | Train Loss: 0.002816 | Test Loss: 0.003587 | lr: 7.8125e-05
# Epoch: 730 | Train Loss: 0.002815 | Test Loss: 0.003586 | lr: 7.8125e-05
# Epoch: 731 | Train Loss: 0.002815 | Test Loss: 0.003586 | lr: 7.8125e-05
# Epoch: 732 | Train Loss: 0.002813 | Test Loss: 0.003583 | lr: 7.8125e-05
# Epoch: 733 | Train Loss: 0.002814 | Test Loss: 0.003584 | lr: 7.8125e-05
# Epoch: 734 | Train Loss: 0.002812 | Test Loss: 0.003582 | lr: 7.8125e-05
# Epoch: 735 | Train Loss: 0.002811 | Test Loss: 0.003581 | lr: 7.8125e-05
# Epoch: 736 | Train Loss: 0.002809 | Test Loss: 0.003579 | lr: 7.8125e-05
# Epoch: 737 | Train Loss: 0.002808 | Test Loss: 0.003578 | lr: 7.8125e-05
# Epoch: 738 | Train Loss: 0.002808 | Test Loss: 0.003578 | lr: 7.8125e-05
# Epoch: 739 | Train Loss: 0.00281 | Test Loss: 0.003578 | lr: 7.8125e-05
# Epoch: 740 | Train Loss: 0.002808 | Test Loss: 0.003577 | lr: 7.8125e-05
# Epoch: 741 | Train Loss: 0.002805 | Test Loss: 0.003574 | lr: 7.8125e-05
# Epoch: 742 | Train Loss: 0.002806 | Test Loss: 0.003574 | lr: 7.8125e-05
# Epoch: 743 | Train Loss: 0.00281 | Test Loss: 0.003577 | lr: 7.8125e-05
# Epoch: 744 | Train Loss: 0.002809 | Test Loss: 0.003577 | lr: 7.8125e-05
# Epoch: 745 | Train Loss: 0.002811 | Test Loss: 0.003576 | lr: 7.8125e-05
# Epoch: 746 | Train Loss: 0.002809 | Test Loss: 0.003575 | lr: 7.8125e-05
# Epoch: 747 | Train Loss: 0.002814 | Test Loss: 0.003577 | lr: 7.8125e-05
# Epoch: 748 | Train Loss: 0.002818 | Test Loss: 0.003581 | lr: 7.8125e-05
# Epoch: 749 | Train Loss: 0.002811 | Test Loss: 0.003574 | lr: 7.8125e-05
# Epoch: 750 | Train Loss: 0.002807 | Test Loss: 0.003572 | lr: 7.8125e-05

# %%
plt.grid()
plt.yscale("log")
plt.plot(losses[:][0], label="Train loss")
plt.plot(losses[:][1], label="Test loss")
plt.xlabel("Epochs")
plt.ylabel("RelL2")
plt.legend()
plt.savefig("KS training")

# %%
data_path = f"../../data/KS/samples/N{N}_CG3_nu0029_T{T}_samples1200.pt"
samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)

cg3 = FunctionSpace(model.mesh, "CG", 3) 
x = assemble(interpolate(SpatialCoordinate(model.mesh)[0], cg3))
grid = torch.tensor(sorted(x.dat.data[:])).to(device=device, dtype=torch.float32)

testset = Dataset(torch.tensor(samples[model.train_samples:]), torch.tensor(grid))

with torch.no_grad():
    predictions = model.network(testset.inputs).detach().cpu().numpy()
# Out:
# /tmp/ipykernel_1753139/1174370896.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# /home/clustor/ma/n/np923/fem_neural_operator/firedrake/src/firedrake/firedrake/interpolation.py:385: FutureWarning: The use of `interpolate` to perform the numerical interpolation is deprecated.
# This feature will be removed very shortly.
#
# Instead, import `interpolate` from the `firedrake.__future__` module to update
# the interpolation's behaviour to return the symbolic `ufl.Interpolate` object associated
# with this interpolation.
#
# You can then assemble the resulting object to get the interpolated quantity
# of interest. For example,
#
# ```
# from firedrake.__future__ import interpolate
# ...
#
# assemble(interpolate(expr, V))
# ```
#
# Alternatively, you can also perform other symbolic operations on the interpolation operator, such as taking
# the derivative, and then assemble the resulting form.
#
#   warnings.warn("""The use of `interpolate` to perform the numerical interpolation is deprecated.
# /tmp/ipykernel_1753139/1174370896.py:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   testset = Dataset(torch.tensor(samples[model.train_samples:]), torch.tensor(grid))

# %%
index = 90
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

prediction = Function(cg3, val=predictions[index, 0, :], name="Network prediction $\hat{u}(x)$")
solution = Function(cg3, val=testset.targets[index, :].detach().cpu().numpy(), name="Firedrake solution $u(x)$")
diff = assemble(solution - prediction)

plot(diff, axes=axes[0], color="red")

plot(Function(cg3, val=testset.inputs[index][0].detach().cpu().numpy(), name="Initial condition $a(x)$"), axes=axes[1])
pred_plot = plot(prediction, axes=axes[1])
plot(solution, axes=axes[1])

axes[0].set_xlabel("$x$")
axes[0].set_ylabel("Error: $u(x) - \hat{u}(x)$")

axes[1].set_xlabel("$x$")

axes[1].legend()

plt.savefig("KS example and error")

# %%
fig, axes = plt.subplots(figsize=(9, 6))

plot(Function(cg3, val=testset.inputs[index][0].detach().cpu().numpy(), name="Initial condition $a(x)$"), axes=axes)
pred_plot = plot(prediction, axes=axes)
plot(solution, axes=axes)

axes.set_xlabel("$x$")

axes.legend()
plt.savefig("KS example")

# %%
fig, axes = plt.subplots(figsize=(9, 6))

plot(diff, axes=axes)
axes.set_xlabel("$x$")
axes.set_ylabel("Error: $u(x) - \hat{u}(x)$")

plt.savefig("KS example error")

# %%
N = 128
T1 = "01"
T2 = "02"

model = KSModel.load(f"../../data/KS/models/CG3/fourier/N{N}/T{T1}/D{64}_M16_samples1000_epoch750.pt", N, T1, device)

cg3 = FunctionSpace(model.mesh, "CG", 3)
x = assemble(interpolate(SpatialCoordinate(model.mesh)[0], cg3))
grid = torch.tensor(sorted(x.dat.data[:])).to(device=device, dtype=torch.float32)

data_path = f"../../data/KS/samples/N{N}_CG3_nu0029_T{T2}_samples1200.pt"
samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)

testset = Dataset(torch.tensor(samples[1000:]), torch.tensor(grid))

with torch.no_grad():
    for _ in range(int(T2) - 1):
        testset.inputs[:, 0, :] = model.network(testset.inputs)[:, 0, :]
        
    predictions = model.network(testset.inputs)[:, 0, :]
# Out:
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/NeuralOperatorModel.py:203: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict, config = torch.load(filename, map_location=device).values()
# /home/clustor/ma/n/np923/fem_neural_operator/fem_neural_operator/classes/ProjectionCoefficient.py:173: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path, map_location=device)
# /tmp/ipykernel_1753139/2254662166.py:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   samples = torch.load(data_path).unsqueeze(2).to(device=device, dtype=torch.float32)
# /tmp/ipykernel_1753139/2254662166.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   testset = Dataset(torch.tensor(samples[1000:]), torch.tensor(grid))

# %%
fig, axes = plt.subplots(figsize=(9, 6))

prediction = Function(cg3, val=predictions[index, :].cpu().numpy(), name="Network prediction $\hat{u}(x)$")
solution = Function(cg3, val=testset.targets[index, :].detach().cpu().numpy(), name="Firedrake solution $u(x)$")
diff = assemble(solution - prediction)

plot(Function(cg3, val=testset.inputs[index][0].detach().cpu().numpy(), name="Initial condition $a(x)$"), axes=axes)
pred_plot = plot(prediction, axes=axes)
plot(solution, axes=axes)

axes.set_xlabel("$x$")

axes.legend()
plt.savefig("KS composition example")
